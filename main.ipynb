# %%
import pandas as pd

# %%
df_microdados = pd.read_csv('MICRODADOS_ENEM_2023.csv', chunksize=100000, sep=';', encoding='ISO-8859-1').get_chunk()

# %%
selectedColumns = ['TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO']

# %%
selectedNotesColumns = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 
       'NU_NOTA_REDACAO']

# %%
display(df_microdados.head(10))
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210059085136    2023               14       M                2
# 1  210059527735    2023               12       M                2
# 2  210061103945    2023                6       F                1
# 3  210060214087    2023                2       F                1
# 4  210059980948    2023                3       F                1
# 5  210058061539    2023                6       F                1
# 6  210059855122    2023               11       F                1
# 7  210058387333    2023               11       M                1
# 8  210059085137    2023                5       F                1
# 9  210060801601    2023               11       M                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               17          1
# 1            1                 0                1               16          1
# 2            1                 1                1                0          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
# 5            3                 1                1                0          1
# 6            3                 1                1               12          1
# 7            3                 1                1               12          1
# 8            2                 1                1                1          1
# 9            1                 1                1                8          1
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# 0  ...     C     C     B    B     A    B     B     A     A     B
# 1  ...     B     A     B    B     A    A     C     A     D     B
# 2  ...     B     A     A    B     A    A     A     A     A     B
# 3  ...     A     A     A    B     A    A     D     A     A     B
# 4  ...     A     A     A    B     A    A     B     A     A     A
# 5  ...     B     A     A    B     A    A     C     A     A     B
# 6  ...     B     A     A    B     A    B     B     A     A     B
# 7  ...     B     A     A    A     A    A     B     A     B     B
# 8  ...     B     A     A    B     A    A     C     A     A     B
# 9  ...     B     A     B    C     B    A     C     A     B     B
#
# [10 rows x 76 columns]

# %%
display(df_microdados.loc[df_microdados['TP_SEXO'] == 'M'])
# Out:
#        NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0      210059085136    2023               14       M                2
# 1      210059527735    2023               12       M                2
# 7      210058387333    2023               11       M                1
# 9      210060801601    2023               11       M                1
# 10     210059085130    2023                8       M                1
# ...             ...     ...              ...     ...              ...
# 99981  210059864203    2023                2       M                1
# 99983  210061153952    2023                3       M                1
# 99986  210060539492    2023                3       M                1
# 99988  210061381639    2023                2       M                1
# 99994  210059708747    2023                3       M                1
#
#        TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0                1                 1                1               17
# 1                1                 0                1               16
# 7                3                 1                1               12
# 9                1                 1                1                8
# 10               3                 1                1                5
# ...            ...               ...              ...              ...
# 99981            2                 1                2                0
# 99983            3                 1                1                1
# 99986            3                 1                2                0
# 99988            1                 1                2                0
# 99994            1                 1                2                0
#
#        TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 0              1  ...     C     C     B    B     A    B     B     A     A
# 1              1  ...     B     A     B    B     A    A     C     A     D
# 7              1  ...     B     A     A    A     A    A     B     A     B
# 9              1  ...     B     A     B    C     B    A     C     A     B
# 10             1  ...     B     A     B    B     A    A     E     A     B
# ...          ...  ...   ...   ...   ...  ...   ...  ...   ...   ...   ...
# 99981          2  ...     B     A     A    B     A    A     D     A     A
# 99983          1  ...     B     A     A    B     A    A     C     A     B
# 99986          2  ...     A     A     A    B     A    A     B     A     A
# 99988          2  ...     A     A     A    B     A    A     D     A     A
# 99994          3  ...     B     A     A    C     B    B     D     A     B
#
#        Q025
# 0         B
# 1         B
# 7         B
# 9         B
# 10        B
# ...     ...
# 99981     B
# 99983     B
# 99986     B
# 99988     B
# 99994     B
#
# [30189 rows x 76 columns]

# %%
display(df_microdados.loc[df_microdados['TP_SEXO'] == 'F'])
# Out:
#        NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 2      210061103945    2023                6       F                1
# 3      210060214087    2023                2       F                1
# 4      210059980948    2023                3       F                1
# 5      210058061539    2023                6       F                1
# 6      210059855122    2023               11       F                1
# ...             ...     ...              ...     ...              ...
# 99995  210061381642    2023                7       F                1
# 99996  210059149704    2023                3       F                1
# 99997  210061153953    2023               12       F                2
# 99998  210060396713    2023                4       F                1
# 99999  210060539501    2023                7       F                1
#
#        TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 2                1                 1                1                0
# 3                3                 1                2                0
# 4                3                 1                2                0
# 5                3                 1                1                0
# 6                3                 1                1               12
# ...            ...               ...              ...              ...
# 99995            1                 1                1                1
# 99996            3                 1                2                0
# 99997            3                 1                1               17
# 99998            3                 1                1                2
# 99999            3                 1                1                2
#
#        TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 2              1  ...     B     A     A    B     A    A     A     A     A
# 3              2  ...     A     A     A    B     A    A     D     A     A
# 4              2  ...     A     A     A    B     A    A     B     A     A
# 5              1  ...     B     A     A    B     A    A     C     A     A
# 6              1  ...     B     A     A    B     A    B     B     A     A
# ...          ...  ...   ...   ...   ...  ...   ...  ...   ...   ...   ...
# 99995          1  ...     A     A     B    B     A    A     D     A     B
# 99996          2  ...     B     A     A    B     A    A     A     A     A
# 99997          1  ...     B     A     A    B     A    A     C     A     C
# 99998          1  ...     A     A     A    A     A    A     C     A     A
# 99999          1  ...     A     A     A    B     A    A     D     A     A
#
#        Q025
# 2         B
# 3         B
# 4         A
# 5         B
# 6         B
# ...     ...
# 99995     B
# 99996     B
# 99997     B
# 99998     B
# 99999     B
#
# [69811 rows x 76 columns]

# %%
df_selectedNotesColumns = df_microdados.filter(items=selectedNotesColumns)
display(selectedNotesColumns)
# Out:
# ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
